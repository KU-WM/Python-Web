# %%
import pandas as pd
import oracledb

# %%
conn = oracledb.connect(
    user='hr',
    password='tiger',
    dsn='localhost/XEPDB1'          # 호스트명/서비스명
)

cursor = conn.cursor()
print("DB연결 성공!")
# Out:
# DB연결 성공!

# %%
df = pd.read_sql("SELECT * FROM ex3_4", conn)
print(df)
# Out:
#    EMPLOYEE_ID
# 0          100
# 1          101
# 2          102
# 3          103
# 4          104
# C:\Users\human\AppData\Local\Temp\ipykernel_3480\3834252345.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM ex3_4", conn)

# %%
select_sql = 'select employee_id from ex3_4'

# %%
cursor.execute(select_sql)
data = pd.DataFrame(cursor.fetchall())
data
# Out:
#      0
# 0  100
# 1  101
# 2  102
# 3  103
# 4  104
# 5  105
# 6  106
# 7  107
# 8  108

# %%
insert_sql = 'insert into ex3_4(employee_id) values (:1)'
dataset = [(105), (106), (107), (108)]

# %%
dataset = [(val,) for val in dataset]

# %%
type(dataset[0])
# Out:
# tuple

# %%
dataset
# Out:
# [((105,),), ((106,),), ((107,),), ((108,),)]

# %%
cursor.executemany(insert_sql, dataset)

# %%
conn.commit()
print("insert 완료")
# Out:
# insert 완료

# %%
conn.rollback()
print("rollback 완료")
# Out:
# rollback 완료
